# %%
d = {"key": "value" , "key1": "value1"}

# %%
d['key']
# Out:
# 'value'

# %%
# %pip install python-box
from box import ConfigBox
# Out:
# Collecting python-box
#   Downloading python_box-7.3.2-cp313-cp313-win_amd64.whl.metadata (8.3 kB)
# Downloading python_box-7.3.2-cp313-cp313-win_amd64.whl (1.2 MB)
#    ---------------------------------------- 0.0/1.2 MB ? eta -:--:--
#    ---------------------------------------- 0.0/1.2 MB ? eta -:--:--
#    ---------------------------------------- 0.0/1.2 MB ? eta -:--:--
#    ---------------------------------------- 0.0/1.2 MB ? eta -:--:--
#    ---------------------------------------- 0.0/1.2 MB ? eta -:--:--
#    -------- ------------------------------- 0.3/1.2 MB ? eta -:--:--
#    -------- ------------------------------- 0.3/1.2 MB ? eta -:--:--
#    ----------------- ---------------------- 0.5/1.2 MB 513.5 kB/s eta 0:00:02
#    ----------------- ---------------------- 0.5/1.2 MB 513.5 kB/s eta 0:00:02
#    ----------------- ---------------------- 0.5/1.2 MB 513.5 kB/s eta 0:00:02
#    ----------------- ---------------------- 0.5/1.2 MB 513.5 kB/s eta 0:00:02
#    ----------------- ---------------------- 0.5/1.2 MB 513.5 kB/s eta 0:00:02
#    ----------------- ---------------------- 0.5/1.2 MB 513.5 kB/s eta 0:00:02
#    -------------------------- ------------- 0.8/1.2 MB 307.4 kB/s eta 0:00:02
#    -------------------------- ------------- 0.8/1.2 MB 307.4 kB/s eta 0:00:02
#    -------------------------- ------------- 0.8/1.2 MB 307.4 kB/s eta 0:00:02
#    -------------------------- ------------- 0.8/1.2 MB 307.4 kB/s eta 0:00:02
#    ---------------------------------- ----- 1.0/1.2 MB 309.1 kB/s eta 0:00:01
#    ---------------------------------- ----- 1.0/1.2 MB 309.1 kB/s eta 0:00:01
#    ---------------------------------- ----- 1.0/1.2 MB 309.1 kB/s eta 0:00:01
#    ---------------------------------------- 1.2/1.2 MB 301.7 kB/s  0:00:04
# Installing collected packages: python-box
# Successfully installed python-box-7.3.2
# Note: you may need to restart the kernel to use updated packages.

# %%
d2 = ConfigBox({"key": "value" , "key1": "value1"})

# %%
d2
# Out:
# ConfigBox({'key': 'value', 'key1': 'value1'})

# %%
d2.key
# Out:
# 'value'

# %%
def get_prduct(x:int, y:int) -> int:
    return x * y

# %%
get_prduct(x=2, y=3)
# Out:
# 6

# %%
get_prduct(2, "4")
# Out:
# '44'

# %%
# %pip install ensure
from ensure import ensure_annotations
# Out:
# Collecting ensure
#   Downloading ensure-1.0.4-py3-none-any.whl.metadata (10 kB)
# Requirement already satisfied: six>=1.11.0 in c:\users\amanda\.conda\envs\texts\lib\site-packages (from ensure) (1.17.0)
# Downloading ensure-1.0.4-py3-none-any.whl (15 kB)
# Installing collected packages: ensure
# Successfully installed ensure-1.0.4
# Note: you may need to restart the kernel to use updated packages.

# %%
@ensure_annotations
def get_prduct(x:int, y:int) -> int:
    return x * y

# %%
get_prduct(x=2, y=3)
# Out:
# 6
